# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

lung_cancer_df = pd.read_csv("lung_cancer_prediction_dataset.csv")
air_pollution_df = pd.read_csv("global_air_pollution_dataset.csv")

# %%
lung_cancer_df.head(5)
# Out:
#    ID       Country  Population_Size  Age  Gender Smoker  Years_of_Smoking  \
# 0   0         China             1400   80    Male    Yes                30
# 1   1          Iran               84   53    Male     No                 0
# 2   2        Mexico              128   47    Male    Yes                12
# 3   3     Indonesia              273   39  Female     No                 0
# 4   4  South Africa               59   44  Female     No                 0
#
#    Cigarettes_per_Day Passive_Smoker Family_History  ...  \
# 0                  29             No             No  ...
# 1                   0            Yes             No  ...
# 2                   6            Yes             No  ...
# 3                   0             No            Yes  ...
# 4                   0            Yes             No  ...
#
#   Air_Pollution_Exposure Occupational_Exposure  Indoor_Pollution  \
# 0                    Low                   Yes                No
# ...

# %%
air_pollution_df.head(5)
# Out:
#               Country              City  AQI_Value AQI_Category  CO_AQI_Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO_AQI_Category  Ozone_AQI_Value Ozone_AQI_Category  NO2_AQI_Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   NO2_AQI_Category  PM2.5_AQI_Value PM2.5_AQI_Category
# ...

# %%
print(lung_cancer_df.dtypes)
# Out:
# ID                               int64
# Country                         object
# Population_Size                  int64
# Age                              int64
# Gender                          object
# Smoker                          object
# Years_of_Smoking                 int64
# Cigarettes_per_Day               int64
# Passive_Smoker                  object
# Family_History                  object
# Lung_Cancer_Diagnosis           object
# Cancer_Stage                    object
# Survival_Years                   int64
# Adenocarcinoma_Type             object
# Air_Pollution_Exposure          object
# Occupational_Exposure           object
# Indoor_Pollution                object
# Healthcare_Access               object
# Early_Detection                 object
# Treatment_Type                  object
# Developed_or_Developing         object
# Annual_Lung_Cancer_Deaths        int64
# Lung_Cancer_Prevalence_Rate    float64
# Mortality_Rate                 float64
# dtype: object

# %% [markdown]
# # 1. Boxplot of Lung Cancer Deaths Distribution

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=lung_cancer_df['Annual_Lung_Cancer_Deaths'])
plt.title("Boxplot of Lung Cancer Deaths Distribution")
plt.grid()
plt.show()

# %% [markdown]
# # 2. Histogram of PM2.5 AQI Values

# %%
plt.figure(figsize=(8, 5))
plt.hist(air_pollution_df['PM2.5_AQI_Value'], bins=20, edgecolor="black")
plt.xlabel("PM2.5 AQI Value")
plt.ylabel("Frequency")
plt.title("Histogram of PM2.5 AQI Values")
plt.grid()
plt.show()

# %% [markdown]
# # 3. Density Plot of the Lung Cancer Mortality Rate

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(lung_cancer_df['Mortality_Rate'], fill=True)
plt.xlabel("Lung Cancer Mortality Rate")
plt.ylabel("Density")
plt.title("Density Plot of Lung Cancer Mortality Rate")
plt.grid()
plt.show()

# %% [markdown]
# # 4. Scatter Plot with Normal and Logistic Distributions

# %%
normal_values = np.random.normal(loc=0, scale=1, size=100)
logistic_values = np.random.logistic(loc=0, scale=1, size=100)

plt.figure(figsize=(8, 5))
plt.scatter(normal_values, logistic_values, color='brown')
plt.xlabel("Normal Distribution")
plt.ylabel("Logistic Distribution")
plt.title("Scatter Plot of Normal vs Logistic Distribution")
plt.grid()
plt.show()

# %% [markdown]
# # Use the matplotlib library for this graph.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


aqi_values = df['PM2.5_AQI_Value'].dropna()
fig, ax = plt.subplots(figsize=(8, 5))
fig.patch.set_facecolor("#eaeaf2")   
ax.set_facecolor("#dce3f5")  
sns.histplot(aqi_values, bins=30, kde=False, color="blue", alpha=0.5, stat="density", label="Histogram", ax=ax)
sns.kdeplot(aqi_values, color="darkred", linewidth=2, label="Density Plot (KDE)", fill=True, alpha=0.3, ax=ax)

ax.set_title("PM2.5 AQI Distribution with Density Overlay", fontsize=14, fontweight='bold')
ax.set_xlabel("PM2.5 AQI Value", fontsize=12)
ax.set_ylabel("Density", fontsize=12)
ax.legend()
ax.grid(axis="y", linestyle="--", alpha=0.7)
fig.text(0.5, -0.05, "This plot represents the distribution of PM2.5 AQI values with a density overlay.", wrap=True, ha="center", fontsize=10)
plt.show()
